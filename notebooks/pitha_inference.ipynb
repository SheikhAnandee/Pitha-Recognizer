# %% [markdown]
# # Setting Up for Inference

# %%
# !pip install -Uqq fastai fastbook nbdev ddgs==9.5.4

# %%
# ! pip uninstall -y fastprogress
# ! pip install "fastprogress==1.0.3"

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/Pitha Recognizer
# Out:
# /content/drive/My Drive/Pitha Recognizer

# %%
version = 2
img_path = 'test images'
model_path = f'models/pitha-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %% [markdown]
# # Inference 1
#
# Target: Dudh Chitoi Pitha

# %%
img = Image.open(f'{img_path}/unknown_00.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x72>

# %%
model.predict(f'{img_path}/unknown_00.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('dudh chitoi pitha',
#  tensor(9),
#  tensor([2.2807e-09, 5.9082e-09, 2.9823e-09, 1.5696e-08, 7.4870e-08, 5.4173e-10,
#          3.1220e-08, 5.4070e-08, 2.4658e-09, 9.9992e-01, 7.7062e-05, 4.0119e-08,
#          1.2342e-07, 7.1772e-08, 4.3364e-07, 3.5309e-09, 3.7599e-10, 5.7012e-09,
#          1.6218e-07, 1.6449e-09]))

# %% [markdown]
# # Inference 2
#
# Target: Bhapa Pitha

# %%
img = Image.open(f'{img_path}/unknown_01.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x78>

# %%
model.predict(f'{img_path}/unknown_01.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('bhapa pitha',
#  tensor(3),
#  tensor([1.8460e-06, 1.0607e-07, 8.6073e-08, 9.9974e-01, 5.5352e-05, 1.9702e-04,
#          2.5041e-07, 7.4667e-07, 3.6393e-07, 8.9028e-07, 1.2285e-07, 4.8153e-08,
#          4.9333e-08, 6.5976e-07, 2.2373e-06, 8.9591e-07, 4.3595e-08, 8.1548e-07,
#          4.1858e-08, 3.0946e-06]))

# %% [markdown]
# # Inference 3
# Target: Patishapta Pitha

# %%
img = Image.open(f'{img_path}/unknown_02.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/unknown_02.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('patisapta pitha',
#  tensor(16),
#  tensor([2.0242e-08, 3.0281e-07, 3.6547e-07, 3.2093e-08, 8.3118e-08, 4.5303e-04,
#          5.9886e-09, 6.7218e-08, 8.6337e-07, 3.2942e-09, 3.8897e-08, 4.8714e-07,
#          1.3466e-08, 1.6057e-08, 1.4925e-08, 9.5212e-08, 9.9954e-01, 5.8436e-08,
#          4.4320e-09, 3.9678e-08]))

# %% [markdown]
# # Inference 4
# Target: Teler Pitha

# %%
img = Image.open(f'{img_path}/unknown_03.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x72>

# %%
model.predict(f'{img_path}/unknown_03.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('teler pitha',
#  tensor(19),
#  tensor([1.0103e-07, 1.5806e-06, 5.8198e-08, 1.9088e-08, 2.3786e-06, 1.2365e-07,
#          2.4786e-07, 1.9747e-08, 1.1585e-08, 3.3401e-08, 3.9579e-09, 5.8979e-08,
#          2.1609e-07, 1.2860e-06, 1.0521e-07, 2.4605e-06, 3.4944e-09, 1.7179e-05,
#          1.0741e-07, 9.9997e-01]))
